# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Dataset
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

df["job_posted_date"] = pd.to_datetime(df.job_posted_date)

# %%
df_index = df.copy()
df_index.set_index("job_title_short", inplace = True)

df_index.loc["Data Scientist"]
# Out:
#                                                          job_title  \
# job_title_short
# Data Scientist                                   Data Scientist II
# Data Scientist                              Data Science Team Lead
# Data Scientist                                      Data Scientist
# Data Scientist                                      Data Scientist
# Data Scientist   Stage - data scientist – génération ia de donn...
# ...                                                            ...
# Data Scientist                            Data Scientist -50065385
# Data Scientist                     Customer Master Data Specialist
# Data Scientist                Data Scientist- Hybrid Work Location
# Data Scientist                       Data Science Python modelling
# Data Scientist                                  Analytics Engineer
#
#                                       job_location  \
# job_title_short
# Data Scientist                            Anywhere
# ...

# %%
df_index.reset_index(drop=True, inplace=True)

# %%
df_index.index.name = "job_title"
df_index
# Out:
#                                                    job_title  \
# job_title
# 0          Senior Clinical Data Engineer / Principal Clin...
# 1                                               Data Analyst
# 2          Data Engineer/Scientist/Analyst, Mid or Senior...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                     Data Engineer- Sr Jobs
# ...                                                      ...
# 785736                                       DevOps Engineer
# 785737                                      CRM Data Analyst
# 785738                        Commercial Analyst - Start Now
# 785739     Principal Associate, Data Engineer (Remote-Eli...
# 785740                                    AWS System Analyst
#
#                                   job_location                    job_via  \
# job_title
# 0                                Watertown, CT            via Work Nearby
# ...

# %%
df_index.index.name = ""
df_index.reset_index(drop=True, inplace=True)
df_index.set_index("job_posted_date", inplace=True)
df_index.sort_index(ascending=False, inplace=True)

# %%
df_index
# Out:
#                                                              job_title  \
# job_posted_date
# 2023-12-31 23:59:58                               Intelligence analyst
# 2023-12-31 23:59:58  Marketing Data & Analytics Product Owner - Sen...
# 2023-12-31 23:40:32                                Staff engineer data
# 2023-12-31 23:40:31                                      Data engineer
# 2023-12-31 23:40:31                                      Data engineer
# ...                                                                ...
# 2023-01-01 00:00:27          Senior Data Analyst / Platform Experience
# 2023-01-01 00:00:24                                       Data Analyst
# 2023-01-01 00:00:22                                       Data Analyst
# 2023-01-01 00:00:07                                       Data Analyst
# 2023-01-01 00:00:04                                       Data Analyst
#
#                                job_location                      job_via  \
# job_posted_date
# ...

# %%
df_2 = df.copy()
df_pivot = df_2.pivot_table(index="job_title_short", values="salary_year_avg", aggfunc="mean")
df_pivot.reset_index(inplace=True)
df_pivot.set_index("job_title_short", inplace=True)
df_pivot
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst              91082.612833
# Cloud Engineer               111268.453846
# Data Analyst                  93841.907854
# Data Engineer                130125.604250
# Data Scientist               135988.837171
# Machine Learning Engineer    126774.315972
# Senior Data Analyst          113911.363665
# Senior Data Engineer         145840.611624
# Senior Data Scientist        154206.292996
# Software Engineer            113393.760054
