# %%
# importing data
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt 

# importing dataset
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

df["job_posted_date"] = pd.to_datetime(df.job_posted_date)
df["job_skills"] = df["job_skills"].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# dfg = df.groupby("job_title_short").agg(job_count = ("job_title_short", "size"), median_salary = ("salary_year_avg", "median"))


# dfg.plot(kind="scatter", x = "job_count", y = "median_salary")
# plt.ylabel("Median Salary")
# plt.xlabel("Job Count")
# plt.title("Median Salary Paired With Job Title Count")


# for i, job in enumerate(dfg.index):
#     plt.text(dfg["job_count"].iloc[i], dfg["median_salary"].iloc[i], job)

# plt.tight_layout()

# %%
# dfg = df.groupby("job_country").agg(job_count= ("job_title_short","size"), median_salary= ("salary_year_avg","median"))
# dfg = dfg.sort_values(by="job_count", ascending=False).head(7)

# dfg.plot(kind="scatter", x="job_count", y="median_salary")

# for i, job in enumerate(dfg.index):
#     plt.text(dfg["job_count"].iloc[i], dfg["median_salary"].iloc[i], job)

# %%
job_titles = ["Data Analyst", "Data Scientist", "Data Engineer"]
df_filtered = df[df["job_title_short"].isin(job_titles)]

df_filtered = df_filtered.groupby(["job_title_short", "job_schedule_type"]).agg(job_count=("job_title_short", "size"), salary_median=("salary_year_avg", "median")).fillna(0).reset_index()
df_filtered = df_filtered.sort_values(by="job_count", ascending=False)
df_filtered
# Out:
#    job_title_short                    job_schedule_type  job_count  \
# 6     Data Analyst                            Full-time     168975
# 44   Data Engineer                            Full-time     165225
# 77  Data Scientist                            Full-time     153278
# 40   Data Engineer                           Contractor      11492
# 0     Data Analyst                           Contractor      10009
# ..             ...                                  ...        ...
# 93  Data Scientist              Internship and Per diem          1
# 92  Data Scientist             Internship and Full-time          1
# 18    Data Analyst   Full-time, Part-time, and Per diem          1
# 20    Data Analyst  Full-time, Part-time, and Volunteer          1
# 57   Data Engineer   Full-time, Temp work, and Per diem          1
#
#     salary_median
# 6         90000.0
# 44       125000.0
# 77       128816.0
# 40       117500.0
# 0         81000.0
# ..            ...
# 93            0.0
# ...

# %%
fig, ax = plt.subplots(1, 3)
job_number = 5
for i, job in enumerate(job_titles):
    skills_count = df_filtered[df_filtered["job_title_short"] == job].head(job_number)
    skills_count.plot(kind="scatter", x = "job_count", y = "salary_median", ax=ax[i])

    for j in range(len(skills_count)):
        ax[i].text(skills_count["job_count"].iloc[j],
                   skills_count["salary_median"].iloc[j],
                   skills_count["job_schedule_type"].iloc[j],
                   fontsize=9)
        
plt.tight_layout()

# Jesus my head hurts! :o
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, ax = plt.subplots(1, 3)
#       2 job_number = 5
#       3 for i, job in enumerate(job_titles):
#
# NameError: name 'plt' is not defined
